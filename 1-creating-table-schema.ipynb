# %% [markdown]
# # Example for cleaning an existing dataset and creating a table schema
#
# - Inspecting fields
# - Setting consistent column names
# - Setting correct data types
# - Writing the table schema
# - Creating the data package/directory structure

# %%
import pandas as pd

# %% [markdown]
# # Data inspecting/cleaning

# %%
DATA = pd.read_csv('PMCLs_00-18.csv')
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34510 entries, 0 to 34509
# Data columns (total 18 columns):
# STATION_ID            34510 non-null int64
# STATION_NAME          34510 non-null object
# FULL_STATION_NAME     34510 non-null object
# STATION_NUMBER        34510 non-null object
# STATION_TYPE          34510 non-null object
# LATITUDE              32614 non-null float64
# LONGITUDE             32614 non-null float64
# COUNTY_NAME           34510 non-null object
# SAMPLE_CODE           34510 non-null object
# SAMPLE_DATE           34510 non-null object
# SAMPLE_DEPTH          34311 non-null float64
# SAMPLE_DEPTH_UNITS    34510 non-null object
# PARAMETER             34510 non-null object
# RESULT                33481 non-null float64
# REPORTING_LIMIT       34509 non-null float64
# UNITS                 34510 non-null object
# METHOD_NAME           34510 non-null object
# sampleYear            34510 non-null int64
# dtypes: float64(5), int64(2), object(11)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Column/field names

# %% [markdown]
# From `info()` we see that the column names are in good shape.
#
# The only things to do are:
# - Convert to lowercase
# - Use consistent casing
#
# This can be done either programmatically or manually, or with a mix of the two.

# %%
COLUMN_NAMES_MANUAL = {
    'FULL_STATION_NAME': 'station_name_full',
    'sampleYear': 'sample_year',
}

def get_fixed_name(col):
    # if the input column is not in the dictionary representing manual assignment, simply use str.lower()
    return COLUMN_NAMES_MANUAL.get(col, col.lower())

# %%
DATA = DATA.rename(columns=get_fixed_name)
DATA.columns
# Out:
# Index(['station_id', 'station_name', 'station_name_full', 'station_number',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'sample_depth', 'sample_depth_units', 'parameter',
#        'result', 'reporting_limit', 'units', 'method_name', 'sample_year'],
#       dtype='object')

# %% [markdown]
# ## Categorical fields
#
# - Categorical fields are fields that can have only a limited set of values
#     - Equivalent to "enum" types in most programming languages
# - They are expressed in pandas with the `Categorical` dtype
# - If categorical dtypes are set on a DataFrame column, the corresponding field will have a `constraints.enum` property set wit the correct values when generating the table schema from the DataFrame object
#
# The decision whether a field should be interpreted as categorical or not is sometimes not easy. Inspecting the number of unique values present in the data is a good first criterion:

# %%
DATA.apply(lambda s: s.nunique())
# Out:
# station_id             1101
# station_name           1099
# station_name_full      1092
# station_number         1101
# station_type              3
# latitude                848
# longitude               726
# county_name              37
# sample_code           15748
# sample_date           13895
# sample_depth            119
# sample_depth_units        2
# parameter                 5
# result                 2566
# reporting_limit         113
# units                     3
# method_name               8
# sample_year              19
# dtype: int64

# %% [markdown]
# In this case, `station_type`, `sample_depth_units`, `parameter`, `units` and `method_name` all have below 10 values, so it makes sense to consider them as categorical.
# `sample_year` has low number of values, but it doesn't really represent a category.
# It could be argued that `county_name` should be categorical, but since we know that there are other counties not present in this dataset, we can leave it as it is.
#
# We can inspect the individual values for the categorical candidates to confirm:

# %%
def inspect_values(df, cols):
    separator = '-' * 10
    for col in cols:
        print(separator)
        display(df[col].value_counts())


DATA.pipe(inspect_values, ['station_type', 'sample_depth_units', 'parameter', 'units', 'method_name'])
# Out:
# ----------
# Surface Water    28975
# Groundwater       3608
# Other             1927
# Name: station_type, dtype: int64
# ----------
# Meters    32814
# Feet       1696
# Name: sample_depth_units, dtype: int64
# ----------
# Dissolved Nitrate    10264
# Total Arsenic         7747
# Total Lead            7423
# Total Selenium        7237
# Total Mercury         1839
# Name: parameter, dtype: int64
# ----------
# ug/L    18232
# mg/L    14575
# ng/L     1703
# Name: units, dtype: int64
# ----------
# EPA 1638 (T)            18232
# EPA 300.0 28d Hold       9089
# EPA 200.8 (T)            4156
# EPA 1631 E (T)           1703
# EPA 300.0 48 hr          1175
# EPA 245.1(T)              135
# EPA 200.8 (D)              19
# EPA 200.8 (Hg Total)        1
# Name: method_name, dtype: int64

# %%
def set_as_categorical(df, cols):
    return df.astype({col: 'category' for col in cols})

DATA = DATA.pipe(set_as_categorical, ['station_type', 'sample_depth_units', 'parameter', 'units', 'method_name'])
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34510 entries, 0 to 34509
# Data columns (total 18 columns):
# station_id            34510 non-null int64
# station_name          34510 non-null object
# station_name_full     34510 non-null object
# station_number        34510 non-null object
# station_type          34510 non-null category
# latitude              32614 non-null float64
# longitude             32614 non-null float64
# county_name           34510 non-null object
# sample_code           34510 non-null object
# sample_date           34510 non-null object
# sample_depth          34311 non-null float64
# sample_depth_units    34510 non-null category
# parameter             34510 non-null category
# result                33481 non-null float64
# reporting_limit       34509 non-null float64
# units                 34510 non-null category
# method_name           34510 non-null category
# sample_year           34510 non-null int64
# dtypes: category(5), float64(5), int64(2), object(6)
# memory usage: 3.6+ MB

# %% [markdown]
# ## Datetime fields
#
# As with categorical data, using the native pandas datetime dtypes is not strictly necessary for the purpose of building the table schema, but helps with validation (making sure that the output format is consistent), and we'll have the correct type in the table schema field.
#
# The `to_datetime()` function in the main pandas module should be robust enough to convert automatically from many input formats.

# %%
DATA = (DATA
        .assign(sample_date=lambda d: pd.to_datetime(d.sample_date))
)
# this should give the same result as
# DATA['sample_year'] = pd.to_datetime(DATA['sample_year'])
# but is somewhat more robust
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34510 entries, 0 to 34509
# Data columns (total 18 columns):
# station_id            34510 non-null int64
# station_name          34510 non-null object
# station_name_full     34510 non-null object
# station_number        34510 non-null object
# station_type          34510 non-null category
# latitude              32614 non-null float64
# longitude             32614 non-null float64
# county_name           34510 non-null object
# sample_code           34510 non-null object
# sample_date           34510 non-null datetime64[ns]
# sample_depth          34311 non-null float64
# sample_depth_units    34510 non-null category
# parameter             34510 non-null category
# result                33481 non-null float64
# reporting_limit       34509 non-null float64
# units                 34510 non-null category
# method_name           34510 non-null category
# sample_year           34510 non-null int64
# dtypes: category(5), datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# We see that the `sample_year` column matches exactly the year in `sample_date`. In principle, then, `sample_year` is redundant, and could be dropped.

# %%
DATA[lambda d: d.sample_date.dt.year != d.sample_year]
# Out:
# Empty DataFrame
# Columns: [station_id, station_name, station_name_full, station_number, station_type, latitude, longitude, county_name, sample_code, sample_date, sample_depth, sample_depth_units, parameter, result, reporting_limit, units, method_name, sample_year]
# Index: []

# %% [markdown]
# # Table schema
#
# ## Creating table schema from the DataFrame
#
# The `build_table_schema()` function allows to get a
#
# Few things to note:
# - The output of `build_table_schema()` is a Python object (dictionary)
#     - It can be modified (either manually or programmatically) from within the notebook
# - It must be converted to a string (for copy-pasting) or saved to a file to be used with other applications
#     - Use the `json` module of the standard library for this

# %%
from pandas.io.json import build_table_schema
import json

def get_table_schema(df):
    return build_table_schema(df, index=False, version=False)

json.dumps(DATA.pipe(get_table_schema))
# Out:
# '{"fields": [{"name": "station_id", "type": "integer"}, {"name": "station_name", "type": "string"}, {"name": "station_name_full", "type": "string"}, {"name": "station_number", "type": "string"}, {"name": "station_type", "type": "any", "constraints": {"enum": ["Groundwater", "Other", "Surface Water"]}, "ordered": false}, {"name": "latitude", "type": "number"}, {"name": "longitude", "type": "number"}, {"name": "county_name", "type": "string"}, {"name": "sample_code", "type": "string"}, {"name": "sample_date", "type": "datetime"}, {"name": "sample_depth", "type": "number"}, {"name": "sample_depth_units", "type": "any", "constraints": {"enum": ["Feet", "Meters"]}, "ordered": false}, {"name": "parameter", "type": "any", "constraints": {"enum": ["Dissolved Nitrate", "Total Arsenic", "Total Lead", "Total Mercury", "Total Selenium"]}, "ordered": false}, {"name": "result", "type": "number"}, {"name": "reporting_limit", "type": "number"}, {"name": "units", "type": "any", "constraints": {"enum": ["mg/L", "ng/L", "ug/L"]}, "ordered": false}, {"name": "method_name", "type": "any", "constraints": {"enum": ["EPA 1631 E (T)", "EPA 1638 (T)", "EPA 200.8 (D)", "EPA 200.8 (Hg Total)", "EPA 200.8 (T)", "EPA 245.1(T)", "EPA 300.0 28d Hold", "EPA 300.0 48 hr"]}, "ordered": false}, {"name": "sample_year", "type": "integer"}]}'

# %% [markdown]
# ## Editing the table schema
#
# Although this method works reasonably well, some parts of the table schema cannot be inferred from the existing data and must be filed in manually.
# The most relevant properties are:
# - `title`: the human-readable counterpart to `name` (what one would e.g. use for an axis label in a figure, or on the header of a table in a published format)
# - `description`: the data dictionary entry for the field. It can contain both data knowledge (e.g. additional properties of the data), and, most importantly, domain knowledge, in the form of metadata, specifications, sources, and so on
#
# Unlike `name`, these metadata fields of the table schema are not mandatory, but having them filled in the schema, since it allows to concentrate the information in one place (instead of e.g. maintaining a separate PDF file for the data dictionary).
#
# JSON files are somewhat annoying to edit directly. A few options to make things easier:
# - Using a code editor with good JSON support, such as VSCode
# - Using a dedicated JSON editor (online or offline) such as https://jsoneditoronline.org/
#
# Once the schema is filled in, it can be incorporated within the `datapackage.json` file.

# %% [markdown]
# ----
# # Bonus: Normalizing tables

# %%
def get_normalized(df, pk=None, **kwargs):
    return df.drop_duplicates(subset=pk, **kwargs)

(get_normalized(DATA[[
    'station_id', 'station_name', 'station_name_full', 'station_number', 'station_type',
    'latitude', 'longitude', 'county_name',
    ]],
    pk='station_id')
 .set_index('station_id').sort_index()
)
# Out:
#                     station_name  \
# station_id
# 1                       AMERICAN
# 10                       CLIFTON
# 12          H.O. Banks Headworks
# 73                        COLUSA
# 78                 TWITCHELLPP01
# 80                      CHECK 13
# 87           Del Valle Reservoir
# 99          OR nr Byron Hwy 4 Br
# 114                   SACWSACINT
# 122                BaconAgDrain1
# 127                    CONCOSPP1
# 133                   STATENPP02
# 143                 PROSL@LHOLTR
# 145          Toe Drain YB LISBON
# 154                  OR@Bacon Is
# 158                    SJOAQHWY4
# 189                  MOKSFSTATEN
# 192              LYTLE CRK NR SB
# 218         Castaic Tower Outlet
# 234                     DKA13481
# 259                Del Valle COW
# 266                 Frenchman Lk
# 275                     GKA26966
# 277                     GKA27210
# 278                     GKA27231
# 279                     GKA27253
# 280                     GKA27280
# 282                     GKA27375
# 283                     GKA27728
# 297                 Check 11 1/2
# ...                          ...
# 47161             SutterCo_MW-1D
# 47162                      AV-3A
# 47163                      AV-3B
# 47164                      AV-3C
# 47168              22N01W29N001M
# 47169              22N01W29N002M
# 47170              22N01W29N003M
# 47171              22N01W29N004M
# 47172              21N01W31H001M
# 47175       Clear C NR MO NR Red
# 47176          Paynes C A P Xing
# 47195              29N04W03R002M
# 47196              29N04W03R003M
# 47197              29N04W03R004M
# 47198              29N04W03R005M
# 47199              29N04W03R006M
# 47570                  AB-4 deep
# 47571       AB-4 intermediate-de
# 47572       AB-4 intermediate-sh
# 47573               AB-4 shallow
# 47574                 LCB-5 deep
# 47575         LCB-5 intermediate
# 47576              LCB-5 shallow
# 47577                     SUT-P4
# 47578                     SUT-P3
# 47579                     SUT-P2
# 47580                     SUT-P1
# 47800                 Teerink PP
# 47838         Liberty Cut @ USGS
# 47839       LibCut ds Stairsteps
#
#                                            station_name_full station_number  \
# station_id
# 1                    American River at Water Treatment Plant       A0714010
# 10                                      Clifton Court Intake       KA000000
# 12                     Delta P.P. Headworks at H.O. Banks PP       KA000331
# 73                       Ag Drain on Colusa Basin Main Drain       A0294500
# 78                     Ag Drain on Twitchell Isl., PP. No. 1    B9V80661391
# 80                        CA Aqueduct, Ck 13, O'Neill Outlet       KA007089
# 87                              Lake Del Valle at Glory Hole       DV001000
# 99               Old R. nr. Byron (St 9) (NEAR HWY 4 BRIDGE)    B9D75351342
# 114              Sacramento River at W. Sac Intake Structure       A0210451
# 122                      Ag Drain on Bacon Island, PP. No. 1    B9V75881342
# 127                                Contra Costa PP Number 01       B9591000
# 133                      Ag Drain on Staten Island PP. No. 2    B9V80751335
# 143         Prospect Slough @ S. Tip of Little Holland Tract    B9S81701398
# 145                  Yolo Bypass Toe Drain Below Lisbon Weir    B9D82851352
# 154                                Old River at Bacon Island    B9D75811344
# 158                                   San Joaquin R. @ Hwy 4    B9D75571196
# 189                    Mokelumne River S.F. at Staten Island    B9D80701299
# 192                          Lytle Creek near San Bernardino       Y3165000
# 218                                Castaic Lake Outlet Tower       CA002000
# 234         DRAINAGE INLET AT MILE POST 134.81, CANTUA CREEK       DKA13481
# 259                          Del Valle Conserv. Outlet Works       DV000000
# 266                                       FRENCHMAN LK NR DM       FR001000
# 275               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA26966
# 277               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27210
# 278               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27231
# 279               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27253
# 280               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27280
# 282               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27375
# 283               NON-PROJECT IMPORT STATION (WHEELER RIDGE)       GKA27728
# 297                        CALIFORNIA AQUEDUCT NEAR CHECK 12       KA006633
# ...                                                      ...            ...
# 47161                                          14N02E17C004M  14N02E17C004M
# 47162                                          14N14W34R005M  14N14W34R005M
# 47163                                          14N14W34R006M  14N14W34R006M
# 47164                                          14N14W34R007M  14N14W34R007M
# 47168                                          22N01W29N001M  22N01W29N001M
# 47169                                          22N01W29N002M  22N01W29N002M
# 47170                                          22N01W29N003M  22N01W29N003M
# 47171                                          22N01W29N004M  22N01W29N004M
# 47172                                          21N01W31H001M  21N01W31H001M
# 47175                    Clear Creek near Mouth near Redding       A3601000
# 47176                            Paynes C at Paynes Crossing       A0460200
# 47195                                          29N04W03R002M  29N04W03R002M
# 47196                                          29N04W03R003M  29N04W03R003M
# 47197                                          29N04W03R004M  29N04W03R004M
# 47198                                          29N04W03R005M  29N04W03R005M
# 47199                                          29N04W03R006M  29N04W03R006M
# 47570                                          10N04E31M001M  10N04E31M001M
# 47571                                          10N04E31M002M  10N04E31M002M
# 47572                                          10N04E31M003M  10N04E31M003M
# 47573                                          10N04E31M004M  10N04E31M004M
# 47574                                          13N01E32K001M  13N01E32K001M
# 47575                                          13N01E32K002M  13N01E32K002M
# 47576                                          13N01E32K003M  13N01E32K003M
# 47577                                          11N04E04N001M  11N04E04N001M
# 47578                                          11N04E04N002M  11N04E04N002M
# 47579                                          11N04E04N003M  11N04E04N003M
# 47580                                          11N04E04N004M  11N04E04N004M
# 47800                                  Teerink Pumping Plant       KA027813
# 47838                             Liberty Cut at USGS Piling    B9D81971401
# 47839               Liberty Cut downstream of the Stairsteps    B9D82001400
#
#              station_type  latitude  longitude     county_name
# station_id
# 1           Surface Water   38.5596   -121.417      Sacramento
# 10          Surface Water   37.8298   -121.557    Contra Costa
# 12          Surface Water   37.8019   -121.620         Alameda
# 73          Surface Water   38.7993   -121.725            Yolo
# 78          Surface Water   38.0966   -121.651      Sacramento
# 80          Surface Water   37.0742   -121.015          Merced
# 87          Surface Water   37.6147   -121.746         Alameda
# 99          Surface Water   37.8910   -121.570    Contra Costa
# 114         Surface Water   38.5980   -121.549            Yolo
# 122         Surface Water   37.9794   -121.570     San Joaquin
# 127         Surface Water   37.9788   -121.702    Contra Costa
# 133         Surface Water   38.1252   -121.559     San Joaquin
# 143         Surface Water   38.2835   -121.664          Solano
# 145         Surface Water   38.4749   -121.588            Yolo
# 154         Surface Water   37.9694   -121.572     San Joaquin
# 158         Surface Water   37.9283   -121.328     San Joaquin
# 189         Surface Water   38.1171   -121.499     San Joaquin
# 192         Surface Water   34.2309   -117.483  San Bernardino
# 218         Surface Water   34.5152   -118.610     Los Angeles
# 234         Surface Water   36.4298   -120.296          Fresno
# 259         Surface Water   37.6183   -121.749         Alameda
# 266         Surface Water   39.8944   -120.192          Plumas
# 275         Surface Water   35.0684   -119.141            Kern
# 277         Surface Water   35.0608   -119.099            Kern
# 278         Surface Water   35.0591   -119.095            Kern
# 279         Surface Water   35.0581   -119.091            Kern
# 280         Surface Water   35.0568   -119.086            Kern
# 282         Surface Water   35.0480   -119.074            Kern
# 283         Surface Water   35.0377   -119.021            Kern
# 297         Surface Water   37.1183   -121.057          Merced
# ...                   ...       ...        ...             ...
# 47161         Groundwater   39.0696   -121.778          Sutter
# 47162         Groundwater   39.0254   -123.382       Mendocino
# 47163         Groundwater   39.0254   -123.382       Mendocino
# 47164         Groundwater   39.0254   -123.382       Mendocino
# 47168         Groundwater   39.7264   -122.010           Glenn
# 47169         Groundwater   39.7264   -122.010           Glenn
# 47170         Groundwater   39.7264   -122.010           Glenn
# 47171         Groundwater   39.7264   -122.010           Glenn
# 47172         Groundwater   39.6830   -122.011           Glenn
# 47175       Surface Water   40.5092   -122.380          Shasta
# 47176       Surface Water   40.2758   -122.181          Tehama
# 47195         Groundwater   40.3928   -122.294          Shasta
# 47196         Groundwater   40.3928   -122.294          Shasta
# 47197         Groundwater   40.3928   -122.294          Shasta
# 47198         Groundwater   40.3928   -122.294          Shasta
# 47199         Groundwater   40.3928   -122.294          Shasta
# 47570         Groundwater   38.6669   -121.584      Sacramento
# 47571         Groundwater   38.6669   -121.584      Sacramento
# 47572         Groundwater   38.6669   -121.584      Sacramento
# 47573         Groundwater   38.6669   -121.584      Sacramento
# 47574         Groundwater   38.9169   -121.883          Colusa
# 47575         Groundwater   38.9169   -121.883          Colusa
# 47576         Groundwater   38.9169   -121.883          Colusa
# 47577         Groundwater   38.8236   -121.543          Sutter
# 47578         Groundwater   38.8236   -121.543          Sutter
# 47579         Groundwater   38.8236   -121.543          Sutter
# 47580         Groundwater   38.8236   -121.543          Sutter
# 47800       Surface Water   35.0328   -119.008            Kern
# 47838       Surface Water   38.3289   -121.668            Yolo
# 47839       Surface Water   38.3333   -121.667            Yolo
#
# [1101 rows x 7 columns]
